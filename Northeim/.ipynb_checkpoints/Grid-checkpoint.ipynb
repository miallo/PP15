# %%
import random
import numpy as np
from __future__ import print_function
import math

# %%
def la(x):
    return x*(40000/360)
def lo(x,y):
    return la(x)*sin(pi/2-pi/180*y)

a = 9.961131
b = 51.728028

x0 = lo(a,b)
y0 = la(b)

# %%
with open( "superTiefe.csv", "r" ) as mergeData:
     allData = [line.strip().split('\t') for line in mergeData]
allData = [[float(first), float(second), float(third)] for first,second,third in allData]
print(allData)
# Out:
# [[51.7276166053971, 9.9614517856482, 4.66], [51.7276732670625, 9.9622092582378, 4.78], [51.7278306792041, 9.9631197843793, 4.81], [51.7273182515537, 9.9630357138905, 5.46], [51.7267881380876, 9.9629503022972, 4.15], [51.7266549915557, 9.9621518422011, 2.11], [51.7265479546522, 9.9613056052569, 4.91], [51.726565975744, 9.9605876114312, 2.46], [51.7265257006993, 9.9598082620743, 4.6], [51.7265495053043, 9.9590935371909, 4.76], [51.7264670692866, 9.9583470448944, 4.82], [51.7263681628292, 9.9576665181759, 5.26], [51.726211756516, 9.9570281524304, 4.99], [51.7259279452746, 9.9564780481252, 4.2], [51.7254876858105, 9.956831429163, 4.53], [51.7250958318372, 9.9571525398735, 4.39], [51.7253956525137, 9.9587813951168, 4.99], [51.7256829422449, 9.9601282831374, 5.39], [51.7256243946512, 9.9611477740202, 2.2], [51.7247183947374, 9.9611413199547, 6.96], [51.7245838651915, 9.9596821144316, 5.94], [51.7240168713515, 9.9584929738287, 3.96], [51.7235444253792, 9.9575044959876, 2.65], [51.723123570021, 9.9587326962594, 3.86], [51.723081325229, 9.9601412750873, 4.78], [51.7230673693602, 9.9616444856021, 7.5], [51.7232657270988, 9.9630962312314, 7.27], [51.7231759988253, 9.9646917265001, 6.68], [51.7231278447916, 9.9659244529996, 6.7], [51.7223046999906, 9.9656561482791, 6.65], [51.722063929822, 9.9641688633803, 6.66], [51.7219551327189, 9.9628099054191, 6.2], [51.7218464613442, 9.9613710679207, 6.75], [51.7218467128013, 9.9602350685838, 2.35], [51.7210219335293, 9.9606943968776, 3.22], [51.7210426787396, 9.9620418716315, 3.64], [51.7210762482618, 9.9634044338111, 6.86], [51.7212078441416, 9.9648762121889, 6.95], [51.7203523032849, 9.964775880808, 6.92], [51.7203189433103, 9.9632840696815, 7.04], [51.7202328192552, 9.9619019776676, 3.74], [51.7199645983537, 9.9613289069477, 2.54], [51.7193293339123, 9.9621460586879, 6.81], [51.7195382109394, 9.9637695495132, 7.15], [51.7187552992736, 9.964162912229, 7.06], [51.7185822967922, 9.9628689978365, 2.88], [51.7180442205181, 9.9618811067287, 5.0], [51.7172540165966, 9.9625608790759, 2.51], [51.7174000293498, 9.9640238564554, 6.95], [51.7168041179438, 9.9638247862551, 6.95], [51.7163147824367, 9.9647856038157, 0.59], [51.7220169911643, 9.9626242462638, 4.71], [51.7231495120113, 9.9631493724975, 7.0], [51.7240417236944, 9.9622876290325, 6.87], [51.7247260222693, 9.9612199422065, 6.9], [51.7251476739084, 9.962532212967, 6.91], [51.7252454488089, 9.9632287491206, 1.82], [51.7249849392583, 9.9637284781877, 1.52], [51.7251975881417, 9.9645100906584, 6.84], [51.7254646774863, 9.9654037691746, 6.82], [51.726119387943, 9.9652765318844, 6.95], [51.7261471320425, 9.9642809294257, 3.74], [51.726595060948, 9.9636537116114, 1.66], [51.727037667345, 9.9638464115653, 6.98]]

# %%
xmin=-400
xmax=1000
ymin=-1600
ymax=200

size=2
radius=10

grid = []
for i in range(0, (xmax-xmin)/size):
    grid.append([])
    for j in range(0, (ymax-ymin)/size):
        grid[i].append([xmin+i*size,ymin+j*size,0.0,0.0])
        #print grid[i][j]

# %%
def dist(x1,y1,x2,y2):
    return math.sqrt((x1-x2)**2+(y1-y2)**2)

# %%
for i in range(len(grid)):
    for j in range(len(grid[i])):
        for k in range(len(allData)):
            if(dist(grid[i][j][0],grid[i][j][1],allData[k][0],allData[k][1])<=radius):
                grid[i][j][2]+=allData[k][2]
                grid[i][j][3]+=1.0

# %%
f1=open('./test.txt', 'w+')
for i in range(len(grid)):
    for j in range(len(grid[i])):
        if(grid[i][j][2]!=0.0):
            grid[i][j][2]/=grid[i][j][3]
        print(grid[i][j][0],grid[i][j][1],grid[i][j][2],file=f1)
    print("",file=f1)
f1.close()
